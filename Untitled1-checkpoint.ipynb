# %%
from tika import parser
## 참고 : https://excelsior-cjh.tistory.com/62?category=928322
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\GO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
raw = parser.from_file('sample.pdf')
# print(raw['content'])
# Out:
# 2019-02-28 13:34:31,106 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar to C:\Users\GO\AppData\Local\Temp\tika-server.jar.
# 2019-02-28 13:35:55,461 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server/1.19/tika-server-1.19.jar.md5 to C:\Users\GO\AppData\Local\Temp\tika-server.jar.md5.
# 2019-02-28 13:35:56,194 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# February 27, 2019 12:17:00 AM,  19-00003437,   Version: 1 Risk Rating: LOW
#
# Indicator Report: IcedID Activity Report (Feb 26, 2019)
#
# Operational (OP) Cyber Crime (CC)
#
# Executive Summary
# IcedID is a banking malware that also has Virtual Network Computing (VNC) capability and can also act as a
# downloader, spread across the network, and receive a number of other commands.
#
# Analysis
# Our initial analysis of IcedID shows that it has several similarities to Vawtrak malware, although the malware's code
# appears to have been written completely from scratch. These similarities suggest that the developer behind IcedID
# may have previously worked on Vawtrak development or at least had intimate knowledge of its code. For more
# information on Vawtrak (14-00000132)
#
# The IcedID indicators in the report include controller URLs and nodes. These nodes or controllers are used for
# command and control communications, downloads, and configuration downloads (including injects). Redirect URLs
# are used by the attackers as Man-in-the-Middle servers for targeted entities. IOCs marked as "Attacker" are purely
# malicious. Any IOC marked as "Compromised" has been malicious at one point but may have been remediated. IP
# addresses marked as "Related" often include controller nodes hosted on legitimate infrastructure, possibly
# containing hundreds or thousands of additional hosts.
#
# First Version Publish Date
# February 27, 2019 12:17:00 AM
#
# Tags LOW
#
# Threat Intelligence Tags
#
# Affected Industry
#
# Financial Services
#
# Target Geography
#
# Global
#
# Intended Effect
#
# Credential Theft/Account Takeover
# Financial Theft
#
# Affected System
#
# Users/Application and Software
#
# Motivation
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 1
#
# https://mysight.isightpartners.com/report/full/14-00000132
# https://www.fireeye.com
#
#
# Financial or Economic
#
# Targeted Information
#
# Customer Data
# Financial Data
# Credentials
#
# Tactics, Techniques And Procedures( TTPs)
#
# Man-in-the-middle-attack
# Malware Propagation and Deployment
# Fraud
# Malware Research and Development
#
# Malware Family
#
# IcedID
#
# Technical Indicators & Warnings
#
# Domain: iamther[.]org
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://billiament.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: gregarded[.]website
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: billiament[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: poperitte[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://conniterot[.]com/in.php
#
# IcedID
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 2
#
# https://www.fireeye.com
#
#
# Malware Family: IcedID
#
# Domain: prorogues[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://jirovided.host/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://coastleme[.]biz/in.php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://ygrenevresed.fun/in[.]php
#
# Malware Family: IcedID
#
# Domain: againston[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://ssenis.fun/in[.]php
#
# Malware Family: IcedID
#
# Domain: suprecien[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://olderivers.host/in[.]php
#
# Malware Family: IcedID
#
# Domain: caffort[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# https://genevada.pw/in[.]php
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 3
#
# https://www.fireeye.com
#
#
# URL: https://genevada.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://detecture.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://sufficial.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://sughd.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: priolonis[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://thension.host/in[.]php
#
# Malware Family: IcedID
#
# Domain: sughd[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://companish.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: possils[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: desided[.]biz
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: califah[.]pw
#
# Attacker
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 4
#
# https://www.fireeye.com
#
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: cranetisti[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://matchippsi[.]com/in.php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://decretery.host/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://receden.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: resurround[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: bestcontrol[.]at
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: intesteron[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://preceived.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://cranetisti[.]com/in.php
#
# Malware Family: IcedID
#
# Attacker
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 5
#
# https://www.fireeye.com
#
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://dicarkadar[.]com/in.php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://labadegmc[.]com/in.php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://caffort.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://kepleted.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: whoulatech[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://foxpartsearch[.]com/in.php
#
# Malware Family: IcedID
#
# Domain: naideed[.]fun
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://importhe[.]com/in.php
#
# Malware Family: IcedID
#
# Domain: similater[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://desaercsed.fun/in[.]php
#
# Malware Family: IcedID
#
# Attacker
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 6
#
# https://www.fireeye.com
#
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://similater.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: fillizee[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: confucial[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: lattempted[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: conniterot[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: horridee[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: stracting[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://cypruns[.]com/in.php
#
# Malware Family: IcedID
#
# Domain: detecture[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: dicarkadar[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 7
#
# https://www.fireeye.com
#
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://annamount.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: http://46[.]249[.]62[.]199/tinx86_14[.]exe
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://califah.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://poperitte.host/in[.]php
#
# Malware Family: IcedID
#
# Domain: matchippsi[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: preceived[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://prolinate.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://bestcontrol[.]at/in.php
#
# Malware Family: IcedID
#
# Domain: councial[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: losived[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# IcedID
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 8
#
# https://www.fireeye.com
#
#
# Malware Family: IcedID
#
# Domain: ssenis[.]fun
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: coastleme[.]biz
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: songstend[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: stronour[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://enslocated.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: combarret[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://songstend.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://stronour.host/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://desided[.]biz/in.php
#
# Malware Family: IcedID
#
# Domain: sloucet[.]pw
#
# Identifier: Attacker
#
# network
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 9
#
# https://www.fireeye.com
#
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://possils.host/in[.]php
#
# Malware Family: IcedID
#
# Domain: mediaterki[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: olderivers[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: ygrenevresed[.]fun
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://prorogues.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: foxpartsearch[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: thension[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://resurround.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: scotiation[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: genevada[.]pw
#
# Attacker
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 10
#
# https://www.fireeye.com
#
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://whoulatech[.]com/data100.php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://gregarded.website/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://losived.host/in[.]php
#
# Malware Family: IcedID
#
# Domain: flagration[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: jirovided[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://mediaterki[.]com/in.php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://lattempted.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://suprecien.host/in[.]php
#
# Malware Family: IcedID
#
# Domain: sufficial[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: importhe[.]com
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 11
#
# https://www.fireeye.com
#
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: annamount[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://intesteron[.]com/in.php
#
# Malware Family: IcedID
#
# Domain: enslocated[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://combarret.host/in[.]php
#
# Malware Family: IcedID
#
# Domain: whoisther[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://againston.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: checlusive[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://priolonis.host/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://iamther[.]org/in.php
#
# Malware Family: IcedID
#
# prolinate[.]pw
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 12
#
# https://www.fireeye.com
#
#
# Domain: prolinate[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://scotiation.pw/in[.]php
#
# Malware Family: IcedID
#
# IP: 46.249.62.199
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: receden[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: labadegmc[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: litellusef[.]com
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Domain: decretery[.]host
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://stracting.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://checlusive.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://whoisther[.]com/in.php
#
# Malware Family: IcedID
#
# kepleted[.]pw
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 13
#
# https://www.fireeye.com
#
#
# Domain: kepleted[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: http://46[.]249[.]62[.]199/sw9jkmxqasj[.]exe
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://naideed.fun/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://sloucet.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://councial.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: psychott[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://horridee.pw/in[.]php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://fillizee[.]com/data100.php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://psychott.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: desaercsed[.]fun
#
# Identifier: Attacker
#
# Network Type: network
#
# IcedID
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 14
#
# https://www.fireeye.com
#
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://confucial.pw/in[.]php
#
# Malware Family: IcedID
#
# Domain: companish[.]pw
#
# Identifier: Attacker
#
# Network Type: network
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://litellusef[.]com/in.php
#
# Malware Family: IcedID
#
# Identifier: Attacker
#
# Network Type: url
#
# URL: https://flagration.pw/in[.]php
#
# Malware Family: IcedID
#
# SHA1: a9a3cafab23855b048e0c68b84fa0525d2b59946
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 151040
#
# SHA256: f03f6b811d1f3d607a0328df997f9acf31737e9b1d4151acdaa8f6ef9
# ba9f0e6
#
# Type: fileType
#
# MD5: 9b46a8aba597ccd0e63f6b5f9966ff81
#
# Malware Family: IcedID
#
# SHA1: f9d8cda3b9a519b78f92fa6fe7592fe83d5e6145
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 245760
#
# SHA256: 7f43e3e6c0b173465ce70316c145524ba42efb99aa68e75825341a
# 9af47a4f44
#
# Type: fileType
#
# MD5: 6b52712fa07e43cf4ee4c7c6370c20e9
#
# Malware Family: IcedID
#
# SHA1: 8370ea63875c36a9fa34e7ed0384a34e95981aa9
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 151040
#
# SHA256: 2892066d30f937ed37af47e2fa00d4fe49850c68d5198b384a35232
# 0686b13e6
#
# Type: fileType
#
# MD5: 6d8091e91f66cf3ec7a05a2bb089143f
#
# Malware Family: IcedID
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 15
#
# https://www.fireeye.com
#
#
# SHA1: 8633f84128e45da381337f78dc24100084094c6c
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 42375
#
# SHA256: 6972d6a41702cef38b7344bc9575f304500f7c5d816d38b7ede3fb9
# a0bc8e27d
#
# Type: fileType
#
# MD5: 7f5e23e55ad269f4d1789fbcef5ed4e8
#
# Malware Family: IcedID
#
# SHA1: 4c1b7fe90f60addb8dc75e73a3ffe64657b641ab
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 91024
#
# SHA256: e58715773b3aacc245206ed5ce548e52568d0954fc3755de25d28c
# dfa5b96de5
#
# Type: fileType
#
# MD5: 0310b69a4f161327e6c03326e95bba06
#
# Malware Family: IcedID
#
# SHA1: 6013fefbc7525f9335f66042a9de517d876984a1
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 238082
#
# SHA256: 82af41ce09b7987c3bb7be2211db65b138ccf39d051f919c981d73a
# 5a3add861
#
# Type: fileType
#
# MD5: 922d22804f90e04c4091efb855f2cd28
#
# Malware Family: IcedID
#
# SHA1: fcae789728b8b6700d6ab3ef6b436d4722b120e1
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 119296
#
# SHA256: 2c331edaadd4105ce5302621b9ebe6808aecb787dd73da0b63882
# c709b63ce48
#
# Type: fileType
#
# MD5: 89906a9e037ada1e455b80c17b959027
#
# Malware Family: IcedID
#
# SHA1: 11f4b9b576cf48c0a30cfd081401f4f2c0201806
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 134144
#
# SHA256: 0724f3731e0864e89fcf5616c7494dfce45a94ec5e0d78f02ea274e7
# e77881ec
#
# Type: fileType
#
# MD5: 5f8b5f13c502bc67e0507eaae25feb30
#
# Malware Family: IcedID
#
# 46b70f553540b2add1b71a98184cc308988d4c6c
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 16
#
# https://www.fireeye.com
#
#
# SHA1: 46b70f553540b2add1b71a98184cc308988d4c6c
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 275456
#
# SHA256: f260e420b62c02d09a285145dfff20865a5c310c9c6434284d2b2b9
# a311ef82d
#
# Type: fileType
#
# MD5: e1c8e2365ed35696133645a099666d66
#
# Malware Family: IcedID
#
# SHA1: 16c7a1c93f2d1db1a3454e6c54efa9ebde159f7a
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 270622
#
# SHA256: 59bcf371c4c6bfa5ae0e35659619d707e10549517e05162b00f2d06
# eb902a0a8
#
# Type: fileType
#
# MD5: f6ab4bbb5771895efc4eb6b688ce163e
#
# Malware Family: IcedID
#
# SHA1: 4fd91f5b4c7ca070a830607ec9765c29a22d20e4
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 299520
#
# SHA256: 8fe52778bdade4be49d784749fb566cf4c95d689e724f6d2f36c30be
# ac7077d7
#
# Type: fileType
#
# MD5: 505c2606e80b5011eb430ec512127b14
#
# Malware Family: IcedID
#
# SHA1: 5e0b0bbc9ddf4c53f85acc26141d6d5a81609910
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 363520
#
# SHA256: aeb5a6f7ebe366017ede4a83770f09f049c4a38d2cd288bfc289bb5
# 6614019fe
#
# Type: fileType
#
# MD5: 6f171e8c1f83f78345b56417ded10a03
#
# Malware Family: IcedID
#
# SHA1: 259b52ddff3998be1502cfd19f6ef9b1a3f887ed
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 585728
#
# SHA256: ebd569e45c4da435d47ad28933f173cab7059847e0a6764928548f
# 58cb31588c
#
# Type: fileType
#
# MD5: e1edacfb2d5c3d16210add04a5801d1d
#
# Malware Family: IcedID
#
# SHA1: 0619d0596ef5e6725b399796017fdcfcafe659fd
#
# File Name: UNAVAILABLE
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 17
#
# https://www.fireeye.com
#
#
# Identifier: Attacker
#
# File Size: 2823168
#
# SHA256: bc21e37e7ff59a648d3791c56806b21b2a0cb06b1e0d8587654744
# 57c1e7e939
#
# Type: fileType
#
# MD5: 20f369fd4216757de0d78e8581dd0bb1
#
# Malware Family: IcedID
#
# SHA1: 3167b24fcee561127f420358cbb07b1a93c45785
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 215552
#
# SHA256: 9ac2da666deba0f9daa0ab525e0df32137317bea421c3739adb08b
# 97aa6710e0
#
# Type: fileType
#
# MD5: a323cdba9d1318131728eb5c64047a78
#
# Malware Family: IcedID
#
# SHA1: 90c15f1b260ce8ffd048c8c6f80e79798f9a2c26
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 479232
#
# SHA256: 2bde4f9f9823db04c86a248724539eed4ed6c13f70f2e691c19fc4cfc
# ac90cea
#
# Type: fileType
#
# MD5: 299e1d45680dcf2599116e16829c57da
#
# Malware Family: IcedID
#
# SHA1: 11bf8e3e73ab84db9dfddd5aef33c997ec803a8a
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 245760
#
# SHA256: 4dd14a49243c11cc57e2480b546ee21306d99b278ee6470fe912e9
# 80f31054b1
#
# Type: fileType
#
# MD5: 5f240844f9d5b84171bd5189c498212c
#
# Malware Family: IcedID
#
# SHA1: 6ade3928ab66de02b668700d19e4fb21285c89f7
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 249856
#
# SHA256: 278505d24d6af66e0ec3b03f48b53306e40cfd328a626bcb43880a9
# c31aa9139
#
# Type: fileType
#
# MD5: 3b7cae00491a31224f8ecba6bf436b2d
#
# Malware Family: IcedID
#
# SHA1: 511a5abe08d222ca80084ade8cc217bebce0d054
#
# File Name: UNAVAILABLE
#
# Attacker
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 18
#
# https://www.fireeye.com
#
#
# Identifier: Attacker
#
# File Size: 173056
#
# SHA256: 8e8ce5205bf9c756f2e9534ec78d27d0544e9543046a8ae48f9d344
# e1b2239aa
#
# Type: fileType
#
# MD5: 5b5de9d7e88b5cbcdc59db5b5f5b9553
#
# Malware Family: IcedID
#
# SHA1: 7b70f8a598e8310f4afd1d9e063d28f4e23aeea3
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 479232
#
# SHA256: e24feed929bba81781ca3b9bc1450f1b2dd0290dd4ee06ab2f204d2
# bafe9b9f6
#
# Type: fileType
#
# MD5: 1cbff7b94af862545a9fb711eb1922da
#
# Malware Family: IcedID
#
# SHA1: e60235a7d1ea7ed3ef84a481ff82366e2d228e72
#
# File Name: UNAVAILABLE
#
# Identifier: Attacker
#
# File Size: 456192
#
# SHA256: 9a7d008154270d722f393d886223c19b9c70d2cb4aad80d296627c
# 8b842ef810
#
# Type: fileType
#
# MD5: 6ebebdcb336c704a4ef9132376e3737a
#
# Malware Family: IcedID
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 19
#
# https://www.fireeye.com
#
#
# 5950 Berkshire Lane, Suite 1600 Dallas, TX 75225
#
# This message contains content and links to content which are the property of FireEye, Inc. and are protected by all applicable laws.
#
# This cyber threat intelligence and this message are solely intended for the use of the individual and organization to which it is
#
# addressed and is subject to the subscription Terms and Conditions to which your institution is a party. Onward distribution in part or
#
# in whole of any FireEye proprietary materials or intellectual property is restricted per the terms of agreement. By accessing and using
#
# this and related content and links, you agree to be bound by the subscription .
#
# For more information please visit: https://intelligence.fireeye.com/reports/19-00003437
#
# © 2019, FireEye, Inc. All rights reserved.
#
# MALWARE INTELLIGENCE
#
#  Confidential and Proprietary / Copyright © 2019 FireEye, Inc. All rights reserved. 20
#
# https://www.fireeye.com
# https://intelligence.fireeye.com/reports/19-00003437
# https://www.fireeye.com

# %%
text = raw['content']
# sentences = sent_tokenize(text)
sentences = text.split('.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-74f6edc37744> in <module>()
#       1 text = raw['content']
#       2 # sentences = sent_tokenize(text)
# ----> 3 sentences = text.split('.').split('\n')
#
# AttributeError: 'list' object has no attribute 'split'

# %%
sentences[:1]
# Out:
# ['\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFebruary 27, 2019 12:17:00 AM,  19-00003437,   Version: 1 Risk Rating: LOW\n\nIndicator Report: IcedID Activity Report (Feb 26, 2019)\n\nOperational (OP) Cyber Crime (CC)\n\nExecutive Summary\nIcedID is a banking malware that also has Virtual Network Computing (VNC) capability and can also act as a\ndownloader, spread across the network, and receive a number of other commands']

# %%
sentences[:1][0].split('\n')
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'February 27, 2019 12:17:00 AM,  19-00003437,   Version: 1 Risk Rating: LOW',
#  '',
#  'Indicator Report: IcedID Activity Report (Feb 26, 2019)',
#  '',
#  'Operational (OP) Cyber Crime (CC)',
#  '',
#  'Executive Summary',
#  'IcedID is a banking malware that also has Virtual Network Computing (VNC) capability and can also act as a',
#  'downloader, spread across the network, and receive a number of other commands']

# %%
text[:1000]
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFebruary 27, 2019 12:17:00 AM,  19-00003437,   Version: 1 Risk Rating: LOW\n\nIndicator Report: IcedID Activity Report (Feb 26, 2019)\n\nOperational (OP) Cyber Crime (CC)\n\nExecutive Summary\nIcedID is a banking malware that also has Virtual Network Computing (VNC) capability and can also act as a\ndownloader, spread across the network, and receive a number of other commands.\n\nAnalysis\nOur initial analysis of IcedID shows that it has several similarities to Vawtrak malware, although the malware's code\nappears to have been written completely from scratch. These similarities suggest that the developer behind IcedID\nmay have previously worked on Vawtrak development or at least had intimate knowledge of its code. For more\ninformation on Vawtrak (14-00000132)\n \nThe IcedID indicators in the report include controller URLs and nodes. These nodes or controllers are used for\ncommand and control communications, downloads, and configuration downloads (including injects). Re"

# %%
# This works in python 3
# required python packages
# tabula-py==1.0.0
# PyPDF2==1.26.0
# Pillow==4.0.0
# pdfminer.six==20170720

import os
import shutil
import warnings
from io import StringIO

import requests
import tabula
from PIL import Image
from PyPDF2 import PdfFileWriter, PdfFileReader
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage

warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-49-fb5b2a8c96a0> in <module>()
#      18 from pdfminer.layout import LAParams
#      19 from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
# ---> 20 from pdfminer.pdfpage import PDFPage
#      21
#      22 warnings.filterwarnings("ignore")
#
# ModuleNotFoundError: No module named 'pdfminer.pdfpage'

# %%
# !pip install tabula
# !pip install PyPDF2
# !pip install pdfminer3k
# Out:
# Collecting tabula
#   Downloading https://files.pythonhosted.org/packages/eb/bf/b2084620900655a8c080af9873cc654a8a2b0d7a5a111ca4ba947cd9717d/tabula-1.0.5.tar.gz
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\venv\lib\site-packages (from tabula) (39.1.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\venv\lib\site-packages (from tabula) (1.14.5)
# Building wheels for collected packages: tabula
#   Running setup.py bdist_wheel for tabula: started
#   Running setup.py bdist_wheel for tabula: finished with status 'done'
#   Stored in directory: C:\Users\GO\AppData\Local\pip\Cache\wheels\47\2c\e2\33c0445cb41b20cf2dc01d31664d62ca6aae7e0bf85c0e6a28
# Successfully built tabula
# Installing collected packages: tabula
# Successfully installed tabula-1.0.5
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# !pip install pdfminer3k
# Out:
# Collecting pdfminer3k
#   Downloading https://files.pythonhosted.org/packages/8c/87/cee0aa24f95c287020df7e3936cb51d32b34b05b430759bac15f89ea5ac2/pdfminer3k-1.3.1.tar.gz (4.1MB)
# Requirement already satisfied: pytest>=2.0 in c:\programdata\anaconda3\envs\venv\lib\site-packages (from pdfminer3k) (3.0.7)
# Requirement already satisfied: ply>=3.4 in c:\programdata\anaconda3\envs\venv\lib\site-packages (from pdfminer3k) (3.10)
# Requirement already satisfied: py>=1.4.29 in c:\programdata\anaconda3\envs\venv\lib\site-packages (from pytest>=2.0->pdfminer3k) (1.4.33)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\venv\lib\site-packages (from pytest>=2.0->pdfminer3k) (39.1.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\envs\venv\lib\site-packages (from pytest>=2.0->pdfminer3k) (0.3.9)
# Building wheels for collected packages: pdfminer3k
#   Running setup.py bdist_wheel for pdfminer3k: started
#   Running setup.py bdist_wheel for pdfminer3k: finished with status 'done'
#   Stored in directory: C:\Users\GO\AppData\Local\pip\Cache\wheels\ca\4f\a7\cb601b4fb257d2321ac668b7c6e269176780bd0283eda855d2
# Successfully built pdfminer3k
# Installing collected packages: pdfminer3k
# Successfully installed pdfminer3k-1.3.1
# You are using pip version 18.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
def download_file(url):
    local_filename = url.split('/')[-1]
    local_filename = local_filename.replace("%20", "_")
    r = requests.get(url, stream=True)
    print(r)
    with open(local_filename, 'wb') as f:
        shutil.copyfileobj(r.raw, f)

    return local_filename


class PDFExtractor():
    def __init__(self, url):
        self.url = url

    # Downloading File in local
    def break_pdf(self, filename, start_page=-1, end_page=-1):
        pdf_reader = PdfFileReader(open(filename, "rb"))
        # Reading each pdf one by one
        total_pages = pdf_reader.numPages
        if start_page == -1:
            start_page = 0
        elif start_page < 1 or start_page > total_pages:
            return "Start Page Selection Is Wrong"
        else:
            start_page = start_page - 1

        if end_page == -1:
            end_page = total_pages
        elif end_page < 1 or end_page > total_pages - 1:
            return "End Page Selection Is Wrong"
        else:
            end_page = end_page

        for i in range(start_page, end_page):
            output = PdfFileWriter()
            output.addPage(pdf_reader.getPage(i))
            with open(str(i + 1) + "_" + filename, "wb") as outputStream:
                output.write(outputStream)

    def extract_text_algo_1(self, file):
        pdf_reader = PdfFileReader(open(file, 'rb'))
        # creating a page object
        pageObj = pdf_reader.getPage(0)

        # extracting extract_text from page
        text = pageObj.extractText()
        text = text.replace("\n", "").replace("\t", "")
        return text

    def extract_text_algo_2(self, file):
        pdfResourceManager = PDFResourceManager()
        retstr = StringIO()
        la_params = LAParams()
        device = TextConverter(pdfResourceManager, retstr, codec='utf-8', laparams=la_params)
        fp = open(file, 'rb')
        interpreter = PDFPageInterpreter(pdfResourceManager, device)
        password = ""
        max_pages = 0
        caching = True
        page_num = set()

        for page in PDFPage.get_pages(fp, page_num, maxpages=max_pages, password=password, caching=caching,
                                      check_extractable=True):
            interpreter.process_page(page)

        text = retstr.getvalue()
        text = text.replace("\t", "").replace("\n", "")

        fp.close()
        device.close()
        retstr.close()
        return text

    def extract_text(self, file):
        text1 = self.extract_text_algo_1(file)
        text2 = self.extract_text_algo_2(file)

        if len(text2) > len(str(text1)):
            return text2
        else:
            return text1

    def extarct_table(self, file):

        # Read pdf into DataFrame
        try:
            df = tabula.read_pdf(file, output_format="csv")
        except:
            print("Error Reading Table")
            return

        print("\nPrinting Table Content: \n", df)
        print("\nDone Printing Table Content\n")

    def tiff_header_for_CCITT(self, width, height, img_size, CCITT_group=4):
        tiff_header_struct = '<' + '2s' + 'h' + 'l' + 'h' + 'hhll' * 8 + 'h'
        return struct.pack(tiff_header_struct,
                           b'II',  # Byte order indication: Little indian
                           42,  # Version number (always 42)
                           8,  # Offset to first IFD
                           8,  # Number of tags in IFD
                           256, 4, 1, width,  # ImageWidth, LONG, 1, width
                           257, 4, 1, height,  # ImageLength, LONG, 1, lenght
                           258, 3, 1, 1,  # BitsPerSample, SHORT, 1, 1
                           259, 3, 1, CCITT_group,  # Compression, SHORT, 1, 4 = CCITT Group 4 fax encoding
                           262, 3, 1, 0,  # Threshholding, SHORT, 1, 0 = WhiteIsZero
                           273, 4, 1, struct.calcsize(tiff_header_struct),  # StripOffsets, LONG, 1, len of header
                           278, 4, 1, height,  # RowsPerStrip, LONG, 1, lenght
                           279, 4, 1, img_size,  # StripByteCounts, LONG, 1, size of extract_image
                           0  # last IFD
                           )

    def extract_image(self, filename):
        number = 1
        pdf_reader = PdfFileReader(open(filename, 'rb'))

        for i in range(0, pdf_reader.numPages):

            page = pdf_reader.getPage(i)

            try:
                xObject = page['/Resources']['/XObject'].getObject()
            except:
                print("No XObject Found")
                return

            for obj in xObject:

                try:

                    if xObject[obj]['/Subtype'] == '/Image':
                        size = (xObject[obj]['/Width'], xObject[obj]['/Height'])
                        data = xObject[obj]._data
                        if xObject[obj]['/ColorSpace'] == '/DeviceRGB':
                            mode = "RGB"
                        else:
                            mode = "P"

                        image_name = filename.split(".")[0] + str(number)

                        print(xObject[obj]['/Filter'])

                        if xObject[obj]['/Filter'] == '/FlateDecode':
                            data = xObject[obj].getData()
                            img = Image.frombytes(mode, size, data)
                            img.save(image_name + "_Flate.png")
                            # save_to_s3(imagename + "_Flate.png")
                            print("Image_Saved")

                            number += 1
                        elif xObject[obj]['/Filter'] == '/DCTDecode':
                            img = open(image_name + "_DCT.jpg", "wb")
                            img.write(data)
                            # save_to_s3(imagename + "_DCT.jpg")
                            img.close()
                            number += 1
                        elif xObject[obj]['/Filter'] == '/JPXDecode':
                            img = open(image_name + "_JPX.jp2", "wb")
                            img.write(data)
                            # save_to_s3(imagename + "_JPX.jp2")
                            img.close()
                            number += 1
                        elif xObject[obj]['/Filter'] == '/CCITTFaxDecode':
                            if xObject[obj]['/DecodeParms']['/K'] == -1:
                                CCITT_group = 4
                            else:
                                CCITT_group = 3
                            width = xObject[obj]['/Width']
                            height = xObject[obj]['/Height']
                            data = xObject[obj]._data  # sorry, getData() does not work for CCITTFaxDecode
                            img_size = len(data)
                            tiff_header = self.tiff_header_for_CCITT(width, height, img_size, CCITT_group)
                            img_name = image_name + '_CCITT.tiff'
                            with open(img_name, 'wb') as img_file:
                                img_file.write(tiff_header + data)

                            # save_to_s3(img_name)
                            number += 1
                except:
                    continue

        return number

    def read_pages(self, start_page=-1, end_page=-1):

        # Downloading file locally
        downloaded_file = download_file(self.url)
        print(downloaded_file)

        # breaking PDF into number of pages in diff pdf files
        self.break_pdf(downloaded_file, start_page, end_page)

        # creating a pdf reader object
        pdf_reader = PdfFileReader(open(downloaded_file, 'rb'))

        # Reading each pdf one by one
        total_pages = pdf_reader.numPages

        if start_page == -1:
            start_page = 0
        elif start_page < 1 or start_page > total_pages:
            return "Start Page Selection Is Wrong"
        else:
            start_page = start_page - 1

        if end_page == -1:
            end_page = total_pages
        elif end_page < 1 or end_page > total_pages - 1:
            return "End Page Selection Is Wrong"
        else:
            end_page = end_page

        for i in range(start_page, end_page):
            # creating a page based filename
            file = str(i + 1) + "_" + downloaded_file

            print("\nStarting to Read Page: ", i + 1, "\n -----------===-------------")

            file_text = self.extract_text(file)
            print(file_text)
            self.extract_image(file)

            self.extarct_table(file)
            os.remove(file)
            print("Stopped Reading Page: ", i + 1, "\n -----------===-------------")

        os.remove(downloaded_file)


# I have tested on these 3 pdf files
# url = "http://s3.amazonaws.com/NLP_Project/Original_Documents/Healthcare-January-2017.pdf"
url = "http://s3.amazonaws.com/NLP_Project/Original_Documents/Sample_Test.pdf"
# url = "http://s3.amazonaws.com/NLP_Project/Original_Documents/Sazerac_FS_2017_06_30%20Annual.pdf"
# creating the instance of class
pdf_extractor = PDFExtractor(url)

# Getting desired data out
pdf_extractor.read_pages(15, 23)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-38-d5ec3e0238f6> in <module>()
#      12
#      13 import requests
# ---> 14 import tabula
#      15 from PIL import Image
#      16 from PyPDF2 import PdfFileWriter, PdfFileReader
#
# ModuleNotFoundError: No module named 'tabula'
